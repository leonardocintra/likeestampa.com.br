# %% [markdown]
# # Transformar imagem PNG para JPG Cloudinary

# %%
# !pip install pandas openpyxl pyautogui Pillow

# %% [markdown]
# ### Observacao
# No ubuntuo precisa fazer isso
# ```
# sudo apt-get install xclip
# ```

# %%
import pandas as pd
import pyautogui
import pyperclip
import time
from PIL import Image


# Passo 1: selecionar IDs das imagens
imagens = [
    'aay6ldbr7q6y8guhnodn',
    'yfo5sjtvqmvreqe5fciw',
    'eoterzkk3onzajp1tc2p',
    'abyj2mmff0si4qtqnpvz',
    'jfeb6qoj4coiz948hg5x',
    'qu0ax6l2n2ugitydunkq',
    'ohfwamygeoregoljt6ev',
    'jodbe8n9xmut0qgz5kin',
    'd029e1bxz6dk5icsvqqp',
    'ekuvqr4p2gf2youy3j1o',
    'wrpza8r4xgcbtyqqsfg6',
    'u8twbky1m3eywkh49mow',
    'opyu1ywixanrd2bbsvhp',
    'ybqnvpp1tksbax87bjyc',
    'a5ggemexbh5xjt8rcv94',
    'uljomqemwqwnm4puvbd3',
    'h4yapwoqwejae8x3ilzx',
    'aysg6rhrncgaw9ughog1',
    'yim2m7cjjz8uvkxnjw4f',
    'ebfzghxegap2enrh0js6',
    'qjaswsgttcstgcb830tp',
    'vl7dt1pxb5wsuqi6aebo',
    'momgp8anpry5l6kxbpst',
    'jcxudtwjsypesww22pjk',
    'xaju8wtxelebfekkix6l',
    'xntysuiw7wrosnbglvn1',
    'bcetairq0ajv9egdxb1a',
    'pmrrrt18djlqehnws7ms',
    'tt8jtbgrn8t3ooljacdq',
    'lkn0axxjmntdgvf8ax02',
    'glnuhhqjgjjbfojniuuh',
    'i9r47tu1zzljprv2pj7y',
    'u1rivhm1zihenkoj1xnp',
    'yrad6kh4r30esjixrr07',
    'ub7univpeoxgpltjrbxr',
    'ntfnflobhhrvg0ujjx7o',
    'yuf1o0flagaiobgbk7qq',
    'uhojotcuaes7kvjz8oob',
    'fl6nkkkg9wedps42evrm',
    'mzkecsldgvnlc57co3th',
    'jwdwh3mscal8ap1cnimw',
    'hbybt5elcmfkvtbc80nv',
    'dnkmt8bdlxi831wkfn5b',
    'ixu8gv2nhsvlk15kfjgi',
    'szvvsf3yuoaeehqdiiei',
    'brffiagkacduu7cetc4y',
    'ekv1cjdsx38okx2rusbp',
    'cwzp3ktlutfbd2bv5gin',
    'm5noolf2mjcgxrry6g0t',
    'dqeloltmtmosncpvquip',
    'y5ct1tgfztc520thkhh4',
    'iv7nfkqhpevu9mcl6fd5',
    'eu0vzyaypgmblaztpijp',
    'oetuvqwjxxpufmoclvy2',
    'svyiugu6tyrzg1wkbq8u'
]

count = len(imagens)

# Passo 2: ler o id da imagem no excel
for img in imagens:
    pyperclip.copy(img)
    time.sleep(2)
    pyautogui.click(x=2882, y=612)
    time.sleep(2)
    
    # Passo 3: buscar no cloudinary
    pyautogui.hotkey("ctrl", "v")
    time.sleep(1)
    pyautogui.press("enter")
    time.sleep(5)
    pyautogui.click(x=2151, y=853)
    time.sleep(1)
    
    # Passo 4: deletar a imagem PNG
    pyautogui.click(x=2206, y=1173)
    time.sleep(2)
    pyautogui.click(x=2803, y=972)
    time.sleep(3)
    
    # Passo 5: renomear para o nome correto
    pyautogui.click(x=2067, y=923, clicks=2)
    time.sleep(2)
    pyautogui.click(x=2244, y=563, clicks=2)
    time.sleep(1)
    pyautogui.hotkey("ctrl", "v")
    time.sleep(1)
    pyautogui.press("enter")
    time.sleep(5)
    pyautogui.click(x=1951, y=571) 
    time.sleep(2)
    
    
    count = count - 1
    print("Fim IMG " + img + " - Falta: " + str(count))
# Out:
# Fim IMG aay6ldbr7q6y8guhnodn - Falta: 54
# Fim IMG yfo5sjtvqmvreqe5fciw - Falta: 53
# Fim IMG eoterzkk3onzajp1tc2p - Falta: 52
# Fim IMG abyj2mmff0si4qtqnpvz - Falta: 51
# Fim IMG jfeb6qoj4coiz948hg5x - Falta: 50
# Fim IMG qu0ax6l2n2ugitydunkq - Falta: 49
# Fim IMG ohfwamygeoregoljt6ev - Falta: 48
# Fim IMG jodbe8n9xmut0qgz5kin - Falta: 47
# Fim IMG d029e1bxz6dk5icsvqqp - Falta: 46
# Fim IMG ekuvqr4p2gf2youy3j1o - Falta: 45
# Fim IMG wrpza8r4xgcbtyqqsfg6 - Falta: 44
# Fim IMG u8twbky1m3eywkh49mow - Falta: 43
# Fim IMG opyu1ywixanrd2bbsvhp - Falta: 42
# Fim IMG ybqnvpp1tksbax87bjyc - Falta: 41
# Fim IMG a5ggemexbh5xjt8rcv94 - Falta: 40
# Fim IMG uljomqemwqwnm4puvbd3 - Falta: 39
# Fim IMG h4yapwoqwejae8x3ilzx - Falta: 38
# Fim IMG aysg6rhrncgaw9ughog1 - Falta: 37
# Fim IMG yim2m7cjjz8uvkxnjw4f - Falta: 36
# Fim IMG ebfzghxegap2enrh0js6 - Falta: 35
# Fim IMG qjaswsgttcstgcb830tp - Falta: 34
# Fim IMG vl7dt1pxb5wsuqi6aebo - Falta: 33
# Fim IMG momgp8anpry5l6kxbpst - Falta: 32
# ...

# %%
# Pede para esperar 5 segundos para poder ir ate a outra aba e ver onde esta o botão
import pyautogui
import time

time.sleep(5)
pyautogui.position()
